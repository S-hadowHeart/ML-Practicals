# %% [markdown]
# # **<u> Tutorial 2 : Implement Linear regression and Logistic regression</u>**

# %% [markdown]
# # Exercise 1 : Implement Simple Linear Regression
# ---
# ## Use the computers.csv dataset and perform the following activities:
# - ### Dataset contains the details of time taken to repair a computer, given the number of units to be repaired.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
computers = pd.read_csv('./datasets/computers.csv')

# %%
computers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Units    14 non-null     int64
#  1   Minutes  14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
computers
# Out:
#     Units  Minutes
# 0       1       23
# 1       2       29
# 2       3       49
# 3       4       64
# 4       4       74
# 5       5       87
# 6       6       96
# 7       6       97
# 8       7      109
# 9       8      119
# 10      9      149
# 11      9      145
# 12     10      154
# 13     10      166

# %%
minutes_model0 = computers['Minutes'].mean()
minutes_model1 = 10 + 12*computers['Units']
minutes_model2 = 6 + 18*computers['Units']

# %%
computers['min_model0'] = minutes_model0
computers['min_model1'] = minutes_model1
computers['min_model2'] = minutes_model2
computers
# Out:
#     Units  Minutes  min_model0  min_model1  min_model2
# 0       1       23   97.214286          22          24
# 1       2       29   97.214286          34          42
# 2       3       49   97.214286          46          60
# 3       4       64   97.214286          58          78
# 4       4       74   97.214286          58          78
# 5       5       87   97.214286          70          96
# 6       6       96   97.214286          82         114
# 7       6       97   97.214286          82         114
# 8       7      109   97.214286          94         132
# 9       8      119   97.214286         106         150
# 10      9      149   97.214286         118         168
# 11      9      145   97.214286         118         168
# 12     10      154   97.214286         130         186
# 13     10      166   97.214286         130         186

# %%
fig, ax = plt.subplots()
# Scatter plot of actual observed data (Units vs Minutes)
ax.scatter(x="Units",y="Minutes",data=computers,label='actual repair time')

# Plot Model 0: constant model using mean of Minutes
ax.plot(computers['Units'],computers['min_model0'],color="red",label='model0')

# Plot Model 1: linear speculated model (Minutes = 10 + 12 × Units)
ax.plot(computers['Units'],computers['min_model1'],color="green",label='model1')

# Plot Model 2: linear speculated model (Minutes = 6 + 18 × Units)
ax.plot(computers['Units'],computers['min_model2'],color="black",label='model2')

# Set Y-axis label
ax.set_ylabel("Minutes")

# Set X-axis label
ax.set_xlabel("Units")

# Set title
ax.set_title("Speculated Models")

# Display legend to identify actual data and models
ax.legend()

# %%
pip install scikit-learn
# Out:
# Running cells with 'Django (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"a:/Sem 6/Django/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## 1. Build Regression model using Scikit-Learn Library(Model 3).

# %% [markdown]
# - ### a. Set the 'Units' column as the input data or predictor column

# %%
X = computers[['Units']]

# %% [markdown]
# -  ### b. Set the 'Minutes' column as the output data

# %%
y = computers['Minutes']

# %% [markdown]
# - ### c. Importing the required class -  LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# -  ### d. Creating a linear regression model

# %%
model = LinearRegression()

# %% [markdown]
# - ### e. Fitting the model to the data

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# - ### f. Fetching intercept and coefficient

# %%
print("Intercept:",model.intercept_)
print("Coefficient:",model.coef_)
# Out:
# Intercept: 4.161654135338296
# Coefficient: [15.50877193]

# %%
# Create Model-3 as manually
computers['min_model3'] = minutes_model3
computers
# Out:
#     Units  Minutes  min_model0  min_model1  min_model2  min_model3
# 0       1       23   97.214286          22          24          19
# 1       2       29   97.214286          34          42          34
# 2       3       49   97.214286          46          60          49
# 3       4       64   97.214286          58          78          64
# 4       4       74   97.214286          58          78          64
# 5       5       87   97.214286          70          96          79
# 6       6       96   97.214286          82         114          94
# 7       6       97   97.214286          82         114          94
# 8       7      109   97.214286          94         132         109
# 9       8      119   97.214286         106         150         124
# 10      9      149   97.214286         118         168         139
# 11      9      145   97.214286         118         168         139
# 12     10      154   97.214286         130         186         154
# 13     10      166   97.214286         130         186         154

# %% [markdown]
# ### 2. Creating Linear Regression model with calculated coefficient and intercept.

# %%
model = LinearRegression()
model.fit(X, y)
print("Intercept:",model.intercept_)
print("Coefficient:",model.coef_)
# Out:
# Intercept: 4.161654135338296
# Coefficient: [15.50877193]

# %% [markdown]
# ### 3. Add the above model to the dataframe for Visualization.

# %%
minutes_model3 = 4 + 15*computers['Units']

# %% [markdown]
# ### 4. Visualize Models using pyplot.

# %%
fig,ax = plt.subplots()

ax.scatter(x="Units",y="Minutes",data=computers,label='actual repair time')

ax.plot(computers['Units'],computers['min_model0'],color="red",label='model0')

ax.plot(computers['Units'],computers['min_model1'],color="green",label='model1')

ax.plot(computers['Units'],computers['min_model2'],color="black",label='model2')

ax.plot(computers['Units'],computers['min_model3'],color="yellow",label='model3')


ax.set_ylabel("Minutes")
ax.set_xlabel("Units")
ax.set_title("Speculated Models")
ax.legend()

# %% [markdown]
# ### 5. Compute the Coefficient of Determination to find accuracy.

# %%
Rsq = model.score(computers[["Units"]],y) * 100
print("R² Value:", Rsq)
# Out:
# R² Value: 98.74371980620737

# %% [markdown]
# ## **Exercise 2 : Multiple Linear Regression Model**
# ---
# std_marks_data.csv
#
# To understand Multiple Linear Regression, let us consider the student marks dataset.
#
# This model helps us to predict the marks of the students using the previous dataset.
#
# The inputs are hours(time spent to study) ,age(present age) and internet(weather the internet is available or not), by using these 3 input fields we are predicting the marks of the students.
#
# ---

# %% [markdown]
# ### 1. Observe data and do some preprocessing.

# %%
student = pd.read_csv('./datasets/std_marks_data.csv')

#its called broadcast
student
# Out:
#      hours  age  internet  marks
# 0     6.84   15         0  78.64
# 1     6.56   20         1  88.80
# 2      NaN   21         1  88.90
# 3     8.67   22         1  98.99
# 4     7.55   17         1  92.34
# ..     ...  ...       ...    ...
# 295   2.99   25         0  43.45
# 296   6.55   15         1  77.74
# 297   0.00   20         1  75.76
# 298   9.90   22         0  99.99
# 299   3.40   21         0  99.99
#
# [300 rows x 4 columns]

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hours     288 non-null    float64
#  1   age       300 non-null    int64
#  2   internet  300 non-null    int64
#  3   marks     300 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 9.5 KB

# %% [markdown]
# ### 2. Find no. of missing values.

# %%
student.isna().sum()
# Out:
# hours       12
# age          0
# internet     0
# marks        0
# dtype: int64

# %% [markdown]
# ### 3. Fill mean value in place of NaN value so NaN value does not affect accuracy.

# %%
student.hours = student.hours.fillna(student.hours.mean())
student.isna().sum()
# Out:
# hours       0
# age         0
# internet    0
# marks       0
# dtype: int64

# %% [markdown]
# ### 4. Segregate input and output.

# %%
x = student.iloc[:, :-1]   #Input features(all columns except last)
x
# Out:
#         hours  age  internet
# 0    6.840000   15         0
# 1    6.560000   20         1
# 2    5.494514   21         1
# 3    8.670000   22         1
# 4    7.550000   17         1
# ..        ...  ...       ...
# 295  2.990000   25         0
# 296  6.550000   15         1
# 297  0.000000   20         1
# 298  9.900000   22         0
# 299  3.400000   21         0
#
# [300 rows x 3 columns]

# %%
y = student.iloc[:, -1:]    #Output variable(last column)
y
# Out:
#      marks
# 0    78.64
# 1    88.80
# 2    88.90
# 3    98.99
# 4    92.34
# ..     ...
# 295  43.45
# 296  77.74
# 297  75.76
# 298  99.99
# 299  99.99
#
# [300 rows x 1 columns]

# %% [markdown]
# ### 5. Prepare model.

# %%
#  Split the dataset into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)


X_train.shape   # Displays the number of rows and columns in training data
# Out:
# (240, 3)

# %%
# Pepare model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
print("Intercept = ", model.intercept_,"\nCoefficients",model.coef_)
# Out:
# Intercept =  [60.34595288]
# Coefficients [[1.1957207  0.20857267 2.53228678]]

# %% [markdown]
# ### 6. Test model with new input data.

# %%
hours = int(input("Enter study hours :"))
age = int(input("Enter age :"))
internet = int(input("enter internet is available or not (0/1) : "))
data = [[hours,age,internet]]
print(model.predict(data))
# Out:
# [[148.84234303]]
# C:\Users\abhij\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## **Exercise 3: Build Logistic Regression Model**
# ---
# Consider a coronary heart disease dataset (chd_data.csv) which lists the age in years ('age') and the presence/absence of evidence of significant coronary heart disease ('chd') for 100 patients.
#
# The variable chd = 0 indicates the absence of coronary heart disease, whereas chd=1 indicates the presence of coronary heart disease.
#
# ---

# %% [markdown]
# ### 1. Import dataset and visualize the data to get an insight on building the model.

# %%
chd = pd.read_csv('./datasets/chd_data.csv')
chd
# Out:
#     age  chd
# 0    20    0
# 1    23    0
# 2    24    0
# 3    25    1
# 4    25    0
# ..  ...  ...
# 95   63    1
# 96   64    1
# 97   64    0
# 98   65    1
# 99   69    1
#
# [100 rows x 2 columns]

# %%
chd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     100 non-null    int64
#  1   chd     100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
chd.isna().sum()
# Out:
# age    0
# chd    0
# dtype: int64

# %%
plt.scatter('age', 'chd', data=chd)
plt.xlabel("Age")
plt.ylabel("chd")
plt.title("Age vs chd")
# Out:
# Text(0.5, 1.0, 'Age vs chd')

# %% [markdown]
# ### 2. Importing the required class

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### 3. Specifying the columns as predictor and target variable

# %%
X = chd[['age']]
y = chd['chd']

# %% [markdown]
# ### 4. Split the data in training and test set in 70:30 ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %% [markdown]
# ### 5. Built model using sklearn.linear_model.LogisticRegression class.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# ### 6. Train the model using the training data

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### 7. Fetch the intercept and the coefficients of the model.

# %%
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Intercept: [-5.6511192]
# Coefficient: [[0.11144141]]

# %% [markdown]
# ### 8. Creating sample data

# %%
test = int(input("Enter age : "))
data = [[test]]

# %% [markdown]
# ### 9. Predicting the probabilities for each of the class labels.

# %%
prediction = model.predict(data)
print("\nPredicted target i.e. 'chd' value :", prediction)
# Out:
# Predicted target i.e. 'chd' value : [0]
# C:\Users\abhij\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### 10. Evaluate the model's performance on training and test data using 'accuracy' measure.

# %%
print("Accuracy score of the model on training data:", model.score(X_train, y_train))
print("Accuracy score of the model on test data:", model.score(X_test, y_test))
# Out:
# Accuracy score of the model on training data: 0.7428571428571429
# Accuracy score of the model on test data: 0.7333333333333333
