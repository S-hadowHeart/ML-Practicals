# %% [markdown]
# # Pandas & Data Visualization Practical Questions

# %% [markdown]
# ## Exercise 3: Explore Pandas Library to Analyze and Manipulate Data

# %% [markdown]
# **Description:**
# Use Pandas library for data analysis and manipulation.
#
# **Dataset:** Sample CSV file
#
# **Task:** Load the dataset, perform data cleaning, manipulation (like sorting, filtering), and exploratory data analysis.

# %% [markdown]
# ### Questions:
# 1. Import NumPy and Pandas library.
# 2. Define a Series with 3 elements.
# 3. Define a Series with a custom index.
# 4. Fetch Series values and index.
# 5. Create a DataFrame from a list of dictionaries.
# 6. Create a sample Excel file on your computer, upload it to Google Drive, and read the Excel file in Google Colab.
# 7. Explore Kaggle and UCI Machine Learning Repository. Search and download the Iris dataset.
# 8. Read the Iris dataset from CSV file format and find the number of rows and columns.
#
# ### Perform the following operations on the Iris dataset:
# 9. Fetch the first 5 and last 5 rows.
# 10. Find the index of the dataset.
# 11. Find column names and rename them as:
#    - `SepalLengthCm` → `Sepal_Length`
#    - `SepalWidthCm` → `Sepal_Width`
#    - `PetalLengthCm` → `Petal_Length`
#    - `PetalWidthCm` → `Petal_Width`
# 12. Replace `"Iris-versicolor"` with `"versicolor"` and similarly replace the other two categories.
# 13. Find the statistical description of the dataset.
# 14. Extract a specific column from the dataset.
# 15. Add a new column using a condition.
# 16. Drop the newly added column.
# 17. Select the first row data.
# 18. Select rows from index 51 to 55.
# 19. Apply conditional formatting on the dataset.
# 20. Print records where species is `"virginica"` and `Petal_Length` is greater than 6.
# 21. Find duplicate values in the dataset.
# 22. Display basic information of the dataset.
# 23. Find null values in the dataset.
# 24. Download the `student_info` dataset and find null values. Fill null values using the mean of the respective column.

# %% [markdown]
# **Dataset Link:**
# https://drive.google.com/drive/folders/1xTZizwH2onTZ8KpW1gttiFZ8SrY8RKOt?usp=sharing

# %% [markdown]
# 25. Import the Adult dataset from UCI Machine Learning Repository and perform the following tasks:
# - Find missing values
# - Identify the type of missing data
# - Handle missing values appropriately

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 4: Visualize Data Using Matplotlib and Seaborn Library

# %% [markdown]
# **Description:**
# Create visualizations using Matplotlib and Seaborn.
#
# **Dataset:** Clean_Dataset
#
# **Task:** Create various plots such as histograms, scatter plots, box plots to visualize the data.

# %% [markdown]
# ### Questions:
# 1. Import NumPy, Pandas, Matplotlib, and Seaborn libraries.
# 2. Download the dataset from Kaggle: **Flight Price Prediction**.
# 3. Read the dataset named `Clean_Dataset`.
# 4. Find the columns present in the dataset.
# 5. Rename column `Unnamed: 0` to `id`.
# 6. Check whether there are any null values in the dataset.
# 7. Find the categories of `source_city`.
# 8. Find the categories of `class`.
# 9. Draw a count plot for `source_city`.
# 10. Draw a count plot for `class`.
# 11. Draw a pie plot for `source_city`.
# 12. Draw a donut plot for `source_city`.
# 13. Draw a histogram plot for `price`.
# 14. Draw a distplot for `price`.
